# %%
import boto3
import json

# Define Minio connection parameters
minio_client = boto3.client(
    's3',
    endpoint_url='http://172.18.0.4:9000',  # Minio IP address from docker inspect
    aws_access_key_id='admin',
    aws_secret_access_key='password',
    region_name='us-east-1'
)

# Specify the bucket and metadata file path
bucket_name = 'warehouse'
metadata_file_key = '/billing/billing_data_raw_a495b294-3183-43d8-a0ad-9354a295b5bc/metadata/00000-381f3e9b-5797-45fc-9416-f5e3b9896c02.metadata.json'  # Example metadata path

# Download the metadata file
metadata_file = minio_client.get_object(Bucket=bucket_name, Key=metadata_file_key)
metadata_content = metadata_file['Body'].read().decode('utf-8')

# Parse and print the metadata content
metadata_json = json.loads(metadata_content)
print(json.dumps(metadata_json, indent=4))
# Out:
# {
#     "format-version": 2,
#     "table-uuid": "6ab223b8-1f83-46ee-9245-68c5688bab2f",
#     "location": "s3://warehouse/billing/billing_data_raw_a495b294-3183-43d8-a0ad-9354a295b5bc",
#     "last-sequence-number": 1,
#     "last-updated-ms": 1732057969236,
#     "last-column-id": 112,
#     "current-schema-id": 0,
#     "schemas": [
#         {
#             "type": "struct",
#             "schema-id": 0,
#             "fields": [
#                 {
#                     "id": 1,
#                     "name": "Business Partner",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 2,
#                     "name": "Industry Code",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 3,
#                     "name": "PSC's IBC",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 4,
#                     "name": "Strategic/NonStrategic",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 5,
#                     "name": "PSC Classification",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 6,
#                     "name": "PSC Department",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 7,
#                     "name": "PSC Ministry",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 8,
#                     "name": "PSC Sub - Dept",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 9,
#                     "name": "PSC - Sub Area",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 10,
#                     "name": "Contract Account (Partner-Independent Data)",
#                     "required": false,
#                     "type": "int"
#                 },
#                 {
#                     "id": 11,
#                     "name": "Posting date in the document",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 12,
#                     "name": "Reversal Indicator",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 13,
#                     "name": "Account Determination ID for Contracts",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 14,
#                     "name": "Billing Document",
#                     "required": false,
#                     "type": "int"
#                 },
#                 {
#                     "id": 15,
#                     "name": "Meter Reader",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 16,
#                     "name": "Meter Reader PR NO.",
#                     "required": false,
#                     "type": "int"
#                 },
#                 {
#                     "id": 17,
#                     "name": "Contract Number: Utilities Industry",
#                     "required": false,
#                     "type": "int"
#                 },
#                 {
#                     "id": 18,
#                     "name": "Consumer Status",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 19,
#                     "name": "Installation Number: Utilities Industry",
#                     "required": false,
#                     "type": "int"
#                 },
#                 {
#                     "id": 20,
#                     "name": "IBC",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 21,
#                     "name": "Billing Class",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 22,
#                     "name": "Supply Guarantee Reason",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 23,
#                     "name": "Rate Category",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 24,
#                     "name": "Region",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 25,
#                     "name": "Cycle Day",
#                     "required": false,
#                     "type": "int"
#                 },
#                 {
#                     "id": 26,
#                     "name": "Industry Type Classification",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 27,
#                     "name": "Ord-Ind-PSC (OIP)",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 28,
#                     "name": "Tariff",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 29,
#                     "name": "BCM/Reversal Reason",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 30,
#                     "name": "Bill Type",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 31,
#                     "name": "Due Date (Print Doc)",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 32,
#                     "name": "Own Consumption",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 33,
#                     "name": "Issue Date (Print Doc's Posting Date)",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 34,
#                     "name": "Legacy Consumer No.",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 35,
#                     "name": "Print Document",
#                     "required": false,
#                     "type": "int"
#                 },
#                 {
#                     "id": 36,
#                     "name": "Revenue Adjustment",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 37,
#                     "name": "Unit Ranges",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 38,
#                     "name": "Unit Ranges Ind.",
#                     "required": false,
#                     "type": "string"
#                 },
#                 {
#                     "id": 39,
#                     "name": "Calendar Year/Month",
#                     "required": false,
#                     "type": "int"
#                 },
#                 {
#                     "id": 40,
#                     "name": "Calendar year/quarter",
#                     "required": false,
#                     "type": "int"
#                 },
#                 {
#                     "id": 41,
#                     "name": "Periodic Quarterly A",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 42,
#                     "name": "GST_RETAILER",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 43,
#                     "name": "Import-OffPeak Units",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 44,
#                     "name": "Import-On Peak Units",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 45,
#                     "name": "GST (Further 1%)",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 46,
#                     "name": "GST (Extra 5%)",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 47,
#                     "name": "GST (Steel Melters)",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 48,
#                     "name": "Import Amt NetMtrng",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 49,
#                     "name": "RET_EMP_BENEF",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 50,
#                     "name": "No. Billing Docs",
#                     "required": false,
#                     "type": "int"
#                 },
#                 {
#                     "id": 51,
#                     "name": "No. of Print Docs",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 52,
#                     "name": "Units Billed",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 53,
#                     "name": "Net Amount",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 54,
#                     "name": "Award Winner Benefit",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 55,
#                     "name": "GST on Retailers (5 %)",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 56,
#                     "name": "GST on Retailers (7.5 %)",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 57,
#                     "name": "Sanctioned Load",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 58,
#                     "name": "Connected Load",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 59,
#                     "name": "Maximum Demand",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 60,
#                     "name": "Additional Surcharge",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 61,
#                     "name": "Electricity Duty",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 62,
#                     "name": "Energy Charges",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 63,
#                     "name": "Fixed Charges",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 64,
#                     "name": "Emp Benefit -Officer",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 65,
#                     "name": "Free Benefit Amount",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 66,
#                     "name": "Fuel Adj. Charges",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 67,
#                     "name": "ISP Adj.",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 68,
#                     "name": "GST",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 69,
#                     "name": "ID Meters",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 70,
#                     "name": "Income Tax",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 71,
#                     "name": "Income Tax Surcharge",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 72,
#                     "name": "Meter Rent",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 73,
#                     "name": "Misc. Energy Charges",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 74,
#                     "name": "PM Relief",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 75,
#                     "name": "Power Factor Penalty",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 76,
#                     "name": "Retro FSA",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 77,
#                     "name": "Sales Tax Adjustment",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 78,
#                     "name": "TVL Fee",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 79,
#                     "name": "LPS Billed",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 80,
#                     "name": "Off Peak Units",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 81,
#                     "name": "On Peak Units",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 82,
#                     "name": "Seasonal Impact",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 83,
#                     "name": "Uniform Qtr.Adj. on Import",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 84,
#                     "name": "Retro FCA Chrgs on Import",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 85,
#                     "name": "Deferred FCA Adj. Im",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 86,
#                     "name": "Deferred FCA Adjustm",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 87,
#                     "name": "Power holding Ltd. S",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 88,
#                     "name": "Surcharge",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 89,
#                     "name": "ISPA Adj. Ind. Peak",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 90,
#                     "name": "Quarterly Adj.",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 91,
#                     "name": "PM Relief Res. Comm.",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 92,
#                     "name": "Uniform Quatrly Adj.",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 93,
#                     "name": "MUCT (KMC)",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 94,
#                     "name": "Kissan Package 2022",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 95,
#                     "name": "New Qtr Adj Import Off Peak",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 96,
#                     "name": "New Qtr Adj Import Peak",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 97,
#                     "name": "New Qtr Adj Export Off Peak",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 98,
#                     "name": "New Qtr Adj Export Peak",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 99,
#                     "name": "Import Units Off Peak \u2013 Current",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 100,
#                     "name": "Import Units Peak \u2013 Current",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 101,
#                     "name": "Import Units Non-TOU \u2013 Current",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 102,
#                     "name": "Uniform Quarterly Ad",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 103,
#                     "name": "Quarterly Adj. Curre",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 104,
#                     "name": "Consp-Non IND-Import",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 105,
#                     "name": "Consp-Non TOD-Import",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 106,
#                     "name": "Normal GST on Import",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 107,
#                     "name": "WithHolding GST -IMP",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 108,
#                     "name": "Withholding ITax-IMP",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 109,
#                     "name": "No. of Print Docs/Bill Docs",
#                     "required": false,
#                     "type": "int"
#                 },
#                 {
#                     "id": 110,
#                     "name": "Zero Rate ISPA",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 111,
#                     "name": "Surcharge_1",
#                     "required": false,
#                     "type": "double"
#                 },
#                 {
#                     "id": 112,
#                     "name": "GST on Marble",
#                     "required": false,
#                     "type": "double"
#                 }
#             ]
#         }
#     ],
#     "default-spec-id": 0,
#     "partition-specs": [
#         {
#             "spec-id": 0,
#             "fields": []
#         }
#     ],
#     "last-partition-id": 999,
#     "default-sort-order-id": 0,
#     "sort-orders": [
#         {
#             "order-id": 0,
#             "fields": []
#         }
#     ],
#     "properties": {
#         "owner": "root",
#         "write.metadata.delete-after-commit.enabled": "false",
#         "gc.enabled": "false",
#         "write.parquet.compression-codec": "zstd"
#     },
#     "current-snapshot-id": 7507475487500495266,
#     "refs": {
#         "main": {
#             "snapshot-id": 7507475487500495266,
#             "type": "branch"
#         }
#     },
#     "snapshots": [
#         {
#             "sequence-number": 1,
#             "snapshot-id": 7507475487500495266,
#             "timestamp-ms": 1732057969236,
#             "summary": {
#                 "operation": "append",
#                 "spark.app.id": "local-1732055597292",
#                 "added-data-files": "1",
#                 "added-records": "100",
#                 "added-files-size": "51710",
#                 "changed-partition-count": "1",
#                 "total-records": "100",
#                 "total-files-size": "51710",
#                 "total-data-files": "1",
#                 "total-delete-files": "0",
#                 "total-position-deletes": "0",
#                 "total-equality-deletes": "0"
#             },
#             "manifest-list": "s3://warehouse/billing/billing_data_raw_a495b294-3183-43d8-a0ad-9354a295b5bc/metadata/snap-7507475487500495266-1-68057ec2-2486-434d-a2f8-bae17a1881d5.avro",
#             "schema-id": 0
#         }
#     ],
#     "statistics": [],
#     "partition-statistics": [],
#     "snapshot-log": [
#         {
#             "timestamp-ms": 1732057969236,
#             "snapshot-id": 7507475487500495266
#         }
#     ],
#     "metadata-log": []
# }
